# %%
import pandas as pd
import numpy as np
#!pip install googlemaps
import googlemaps

gmaps_key = "AIzaSyA0WavkAEvRu8N9ZqDUKyo4tAisTY8Egj4"
gmaps = googlemaps.Client(key=gmaps_key)

crime = pd.read_csv("Data/crime_Seoul2.csv",encoding = 'utf-8', index_col = 0)

####1. 경찰서명 받아오기####
sttns = []
for name in crime['관서명']:
    sttns.append('서울' + name[:-1] + '경찰서')
print(sttns)
# Out:
# ['서울중부경찰서', '서울종로경찰서', '서울남대문경찰서', '서울서대문경찰서', '서울혜화경찰서', '서울용산경찰서', '서울성북경찰서', '서울동대문경찰서', '서울마포경찰서', '서울영등포경찰서', '서울성동경찰서', '서울동작경찰서', '서울광진경찰서', '서울서부경찰서', '서울강북경찰서', '서울금천경찰서', '서울중랑경찰서', '서울강남경찰서', '서울관악경찰서', '서울강서경찰서', '서울강동경찰서', '서울종암경찰서', '서울구로경찰서', '서울서초경찰서', '서울양천경찰서', '서울송파경찰서', '서울노원경찰서', '서울방배경찰서', '서울은평경찰서', '서울도봉경찰서', '서울수서경찰서']

# %%
#연습
tmp2=gmaps.geocode('서울중부경찰서',language='ko')
tmp2[0].get("formatted_address")
tmp3 = tmp2[0].get("geometry")
#위치정보 받기
#print(tmp3['location']['lat'], tmp3['location']['lng'])
lat = tmp3['location']['lat']
lng = tmp3['location']['lng']

# %%
####2. 위치 정보 뽑아오기 ####
# (1) 각각 경찰서의 정보를 gamps에서 가져와 tmp에 저장 ( list고 내부는 섞여있음)
tmp = []
fin_res = []
for sttn in sttns:
    tmp.append(gmaps.geocode(sttn,language='ko'))

#다 풀어서 list에 dict로 저장 
for i in range(0,len(tmp)):
    if len(tmp[i])>1:
        for item in tmp[i]:
            #print(type(item))
            fin_res.append(item)
    else:
        #print(type(tmp[i][0]))
        fin_res.append(tmp[i][0])

fin_res
# Out:
# [{'address_components': [{'long_name': '２７',
#     'short_name': '２７',
#     'types': ['premise']},
#    {'long_name': '수표로',
#     'short_name': '수표로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '을지로동',
#     'short_name': '을지로동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '중구',
#     'short_name': '중구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '100-032',
#     'short_name': '100-032',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 중구 을지로동 수표로 27',
#   'geometry': {'location': {'lat': 37.5636465, 'lng': 126.9895796},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.56499548029149,
#      'lng': 126.9909285802915},
#     'southwest': {'lat': 37.56229751970849, 'lng': 126.9882306197085}}},
#   'place_id': 'ChIJc-9q5uSifDURLhQmr5wkXmc',
#   'plus_code': {'compound_code': 'HX7Q+FR 대한민국 서울특별시',
#    'global_code': '8Q98HX7Q+FR'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '４６',
#     'short_name': '４６',
#     'types': ['premise']},
#    {'long_name': '율곡로',
#     'short_name': '율곡로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '종로1.2.3.4가동',
#     'short_name': '종로1.2.3.4가동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '종로구',
#     'short_name': '종로구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '110-310',
#     'short_name': '110-310',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 종로구 종로1.2.3.4가동 율곡로 46',
#   'geometry': {'location': {'lat': 37.5755578, 'lng': 126.9848674},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5769067802915,
#      'lng': 126.9862163802915},
#     'southwest': {'lat': 37.5742088197085, 'lng': 126.9835184197085}}},
#   'place_id': 'ChIJRVgVHsOifDURFhKFchVo22I',
#   'plus_code': {'compound_code': 'HXGM+6W 대한민국 서울특별시',
#    'global_code': '8Q98HXGM+6W'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '４１０',
#     'short_name': '４１０',
#     'types': ['premise']},
#    {'long_name': '한강대로',
#     'short_name': '한강대로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '회현동',
#     'short_name': '회현동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '중구',
#     'short_name': '중구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '100-095',
#     'short_name': '100-095',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 중구 회현동 한강대로 410',
#   'geometry': {'location': {'lat': 37.5547584, 'lng': 126.9734981},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5561073802915,
#      'lng': 126.9748470802915},
#     'southwest': {'lat': 37.5534094197085, 'lng': 126.9721491197085}}},
#   'place_id': 'ChIJFXNA0GCifDURCtV185R5xD8',
#   'plus_code': {'compound_code': 'HX3F+W9 대한민국 서울특별시',
#    'global_code': '8Q98HX3F+W9'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '１１３',
#     'short_name': '１１３',
#     'types': ['premise']},
#    {'long_name': '통일로',
#     'short_name': '통일로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '충현동',
#     'short_name': '충현동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '서대문구',
#     'short_name': '서대문구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '120-020',
#     'short_name': '120-020',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 서대문구 충현동 통일로 113',
#   'geometry': {'location': {'lat': 37.5647848, 'lng': 126.9667762},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.56613378029149,
#      'lng': 126.9681251802915},
#     'southwest': {'lat': 37.5634358197085, 'lng': 126.9654272197085}}},
#   'place_id': 'ChIJCZy8woiifDURz7CV6Khfi18',
#   'plus_code': {'compound_code': 'HX78+WP 대한민국 서울특별시',
#    'global_code': '8Q98HX78+WP'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '１１２−１６',
#     'short_name': '１１２−１６',
#     'types': ['premise']},
#    {'long_name': '창경궁로',
#     'short_name': '창경궁로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '인의동',
#     'short_name': '인의동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '종로구',
#     'short_name': '종로구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '110-410',
#     'short_name': '110-410',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 종로구 인의동 창경궁로 112-16',
#   'geometry': {'location': {'lat': 37.5718529, 'lng': 126.9989143},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5732018802915,
#      'lng': 127.0002632802915},
#     'southwest': {'lat': 37.5705039197085, 'lng': 126.9975653197085}}},
#   'place_id': 'ChIJc0PIxSCjfDURWuMVOPZrMTM',
#   'plus_code': {'compound_code': 'HXCX+PH 대한민국 서울특별시',
#    'global_code': '8Q98HXCX+PH'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '３２９',
#     'short_name': '３２９',
#     'types': ['premise']},
#    {'long_name': '백범로',
#     'short_name': '백범로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '원효로1가',
#     'short_name': '원효로1가',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '용산구',
#     'short_name': '용산구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '140-111',
#     'short_name': '140-111',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 용산구 원효로1가 백범로 329',
#   'geometry': {'location': {'lat': 37.5387099, 'lng': 126.9659183},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5400588802915,
#      'lng': 126.9672672802915},
#     'southwest': {'lat': 37.5373609197085, 'lng': 126.9645693197085}}},
#   'place_id': 'ChIJhbgEHxKifDURLOHanwAKdJI',
#   'plus_code': {'compound_code': 'GXQ8+F9 대한민국 서울특별시',
#    'global_code': '8Q98GXQ8+F9'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '２４',
#     'short_name': '２４',
#     'types': ['premise']},
#    {'long_name': '원효로89길',
#     'short_name': '원효로89길',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '원효로1가',
#     'short_name': '원효로1가',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '용산구',
#     'short_name': '용산구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '140-111',
#     'short_name': '140-111',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 용산구 원효로1가 원효로89길 24',
#   'geometry': {'location': {'lat': 37.5411211, 'lng': 126.9676935},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.54247008029149,
#      'lng': 126.9690424802915},
#     'southwest': {'lat': 37.53977211970849, 'lng': 126.9663445197085}}},
#   'place_id': 'ChIJAbU8HhOifDUR8hROXOdHGXg',
#   'plus_code': {'compound_code': 'GXR9+C3 대한민국 서울특별시',
#    'global_code': '8Q98GXR9+C3'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '３０１',
#     'short_name': '３０１',
#     'types': ['premise']},
#    {'long_name': '삼선동5가',
#     'short_name': '삼선동5가',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '성북구',
#     'short_name': '성북구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '136-045',
#     'short_name': '136-045',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 성북구 삼선동5가 301',
#   'geometry': {'location': {'lat': 37.5897482, 'lng': 127.0161353},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.59109718029149,
#      'lng': 127.0174842802915},
#     'southwest': {'lat': 37.58839921970849, 'lng': 127.0147863197085}}},
#   'place_id': 'ChIJCzgT1Me8fDURiSAT03pwJPg',
#   'plus_code': {'compound_code': 'H2Q8+VF 대한민국 서울특별시',
#    'global_code': '8Q99H2Q8+VF'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '２９',
#     'short_name': '２９',
#     'types': ['premise']},
#    {'long_name': '약령시로21길',
#     'short_name': '약령시로21길',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '청량리동',
#     'short_name': '청량리동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '동대문구',
#     'short_name': '동대문구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '130-010',
#     'short_name': '130-010',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 동대문구 청량리동 약령시로21길 29',
#   'geometry': {'location': {'lat': 37.58506149999999, 'lng': 127.0457679},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5864104802915,
#      'lng': 127.0471168802915},
#     'southwest': {'lat': 37.5837125197085, 'lng': 127.0444189197085}}},
#   'place_id': 'ChIJKUctL1y7fDURClHzlLM2Ir8',
#   'plus_code': {'compound_code': 'H2PW+28 대한민국 서울특별시',
#    'global_code': '8Q99H2PW+28'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '６１８−１',
#     'short_name': '６１８−１',
#     'types': ['premise']},
#    {'long_name': '아현동',
#     'short_name': '아현동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '마포구',
#     'short_name': '마포구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '121-010',
#     'short_name': '121-010',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 마포구 아현동 618-1',
#   'geometry': {'location': {'lat': 37.550814, 'lng': 126.954028},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5521629802915,
#      'lng': 126.9553769802915},
#     'southwest': {'lat': 37.5494650197085, 'lng': 126.9526790197085}}},
#   'place_id': 'ChIJc8rsjHWifDUR0YQrTyV4_zo',
#   'plus_code': {'compound_code': 'HX23+8J 대한민국 서울특별시',
#    'global_code': '8Q98HX23+8J'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '７５９',
#     'short_name': '７５９',
#     'types': ['premise']},
#    {'long_name': '경인로',
#     'short_name': '경인로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '문래동3가',
#     'short_name': '문래동3가',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '영등포구',
#     'short_name': '영등포구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '150-093',
#     'short_name': '150-093',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 영등포구 문래동3가 경인로 759',
#   'geometry': {'location': {'lat': 37.5135203, 'lng': 126.8976364},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.51486928029149,
#      'lng': 126.8989853802915},
#     'southwest': {'lat': 37.51217131970849, 'lng': 126.8962874197085}}},
#   'place_id': 'ChIJwSsjNfaefDURVZhjdrXrUeA',
#   'plus_code': {'compound_code': 'GV7X+C3 대한민국 서울특별시',
#    'global_code': '8Q98GV7X+C3'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '９',
#     'short_name': '９',
#     'types': ['premise']},
#    {'long_name': '왕십리광장로',
#     'short_name': '왕십리광장로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '행당동',
#     'short_name': '행당동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '성동구',
#     'short_name': '성동구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '133-071',
#     'short_name': '133-071',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 성동구 행당동 왕십리광장로 9',
#   'geometry': {'location': {'lat': 37.5617309, 'lng': 127.0363806},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5630798802915,
#      'lng': 127.0377295802915},
#     'southwest': {'lat': 37.5603819197085, 'lng': 127.0350316197085}}},
#   'place_id': 'ChIJA8Pio1mjfDURAN4B7oLFW4E',
#   'plus_code': {'compound_code': 'H26P+MH 대한민국 서울특별시',
#    'global_code': '8Q99H26P+MH'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '１４８',
#     'short_name': '１４８',
#     'types': ['premise']},
#    {'long_name': '노량진로',
#     'short_name': '노량진로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '노량진1동',
#     'short_name': '노량진1동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '동작구',
#     'short_name': '동작구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '156-051',
#     'short_name': '156-051',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 동작구 노량진1동 노량진로 148',
#   'geometry': {'location': {'lat': 37.5130866, 'lng': 126.9428498},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5144355802915,
#      'lng': 126.9441987802915},
#     'southwest': {'lat': 37.51173761970851, 'lng': 126.9415008197085}}},
#   'place_id': 'ChIJB3ImbmiffDUR7BOlDuasX44',
#   'plus_code': {'compound_code': 'GW7V+64 대한민국 서울특별시',
#    'global_code': '8Q98GW7V+64'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '１６７',
#     'short_name': '１６７',
#     'types': ['premise']},
#    {'long_name': '자양로',
#     'short_name': '자양로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '구의동',
#     'short_name': '구의동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '광진구',
#     'short_name': '광진구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '143-201',
#     'short_name': '143-201',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 광진구 구의동 자양로 167',
#   'geometry': {'location': {'lat': 37.542873, 'lng': 127.083821},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5442219802915,
#      'lng': 127.0851699802915},
#     'southwest': {'lat': 37.5415240197085, 'lng': 127.0824720197085}}},
#   'place_id': 'ChIJNbvWaSelfDURIjHmxaVUnBA',
#   'plus_code': {'compound_code': 'G3VM+4G 대한민국 서울특별시',
#    'global_code': '8Q99G3VM+4G'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '７５７',
#     'short_name': '７５７',
#     'types': ['premise']},
#    {'long_name': '통일로',
#     'short_name': '통일로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '대조동',
#     'short_name': '대조동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '은평구',
#     'short_name': '은평구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '122-030',
#     'short_name': '122-030',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 은평구 대조동 통일로 757',
#   'geometry': {'location': {'lat': 37.6128611, 'lng': 126.9274951},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.61421008029149,
#      'lng': 126.9288440802915},
#     'southwest': {'lat': 37.61151211970849, 'lng': 126.9261461197085}}},
#   'place_id': 'ChIJv6JEmDCYfDUR_RfmrfxsE-A',
#   'plus_code': {'compound_code': 'JW7G+4X 대한민국 서울특별시',
#    'global_code': '8Q98JW7G+4X'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '４０６',
#     'short_name': '４０６',
#     'types': ['premise']},
#    {'long_name': '오패산로',
#     'short_name': '오패산로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '번1동',
#     'short_name': '번1동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '강북구',
#     'short_name': '강북구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '142-060',
#     'short_name': '142-060',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 강북구 번1동 오패산로 406',
#   'geometry': {'location': {'lat': 37.63730390000001, 'lng': 127.0273399},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.63865288029151,
#      'lng': 127.0286888802915},
#     'southwest': {'lat': 37.63595491970851, 'lng': 127.0259909197085}}},
#   'place_id': 'ChIJ_wkrvRG8fDURn_RnVb8f8tM',
#   'plus_code': {'compound_code': 'J2PG+WW 대한민국 서울특별시',
#    'global_code': '8Q99J2PG+WW'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '１９０',
#     'short_name': '１９０',
#     'types': ['premise']},
#    {'long_name': '시흥동',
#     'short_name': '시흥동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '금천구',
#     'short_name': '금천구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '153-031',
#     'short_name': '153-031',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 금천구 시흥동 190',
#   'geometry': {'location': {'lat': 37.4568722, 'lng': 126.8970429},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.4582211802915,
#      'lng': 126.8983918802915},
#     'southwest': {'lat': 37.4555232197085, 'lng': 126.8956939197085}}},
#   'place_id': 'ChIJ2-RavjKefDURmXUg-JJ7fwk',
#   'plus_code': {'compound_code': 'FV4W+PR 대한민국 서울특별시',
#    'global_code': '8Q98FV4W+PR'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '４０−１０',
#     'short_name': '４０−１０',
#     'types': ['premise']},
#    {'long_name': '신내역로3길',
#     'short_name': '신내역로3길',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '신내1동',
#     'short_name': '신내1동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '중랑구',
#     'short_name': '중랑구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '131-130',
#     'short_name': '131-130',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 중랑구 신내1동 신내역로3길 40-10',
#   'geometry': {'location': {'lat': 37.618692, 'lng': 127.1047136},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.62004098029149,
#      'lng': 127.1060625802915},
#     'southwest': {'lat': 37.61734301970849, 'lng': 127.1033646197085}}},
#   'place_id': 'ChIJ2bFnYx-6fDURfctUJGeqD44',
#   'plus_code': {'compound_code': 'J493+FV 대한민국 서울특별시',
#    'global_code': '8Q99J493+FV'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '９９８',
#     'short_name': '９９８',
#     'types': ['premise']},
#    {'long_name': '대치동',
#     'short_name': '대치동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '강남구',
#     'short_name': '강남구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '135-282',
#     'short_name': '135-282',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 강남구 대치동 998',
#   'geometry': {'location': {'lat': 37.5094352, 'lng': 127.0669578},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5107841802915,
#      'lng': 127.0683067802915},
#     'southwest': {'lat': 37.5080862197085, 'lng': 127.0656088197085}}},
#   'place_id': 'ChIJcbaB0UakfDURoyy8orQOWFg',
#   'plus_code': {'compound_code': 'G358+QQ 대한민국 서울특별시',
#    'global_code': '8Q99G358+QQ'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '봉천동',
#     'short_name': '봉천동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '관악구',
#     'short_name': '관악구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '151-050',
#     'short_name': '151-050',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 관악구 봉천동',
#   'geometry': {'location': {'lat': 37.4743789, 'lng': 126.9509748},
#    'location_type': 'GEOMETRIC_CENTER',
#    'viewport': {'northeast': {'lat': 37.4757278802915,
#      'lng': 126.9523237802915},
#     'southwest': {'lat': 37.4730299197085, 'lng': 126.9496258197085}}},
#   'place_id': 'ChIJIcPY0_SffDURRUZI3LvvKiU',
#   'plus_code': {'compound_code': 'FXF2+Q9 대한민국 서울특별시',
#    'global_code': '8Q98FXF2+Q9'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '７３',
#     'short_name': '７３',
#     'types': ['premise']},
#    {'long_name': '화곡로',
#     'short_name': '화곡로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '신월동',
#     'short_name': '신월동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '양천구',
#     'short_name': '양천구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '158-090',
#     'short_name': '158-090',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 양천구 신월동 화곡로 73',
#   'geometry': {'location': {'lat': 37.5397827, 'lng': 126.8299968},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.54113168029149,
#      'lng': 126.8313457802915},
#     'southwest': {'lat': 37.53843371970849, 'lng': 126.8286478197085}}},
#   'place_id': 'ChIJYW3jRBScfDURCY2dwRu1wAQ',
#   'plus_code': {'compound_code': 'GRQH+WX 대한민국 서울특별시',
#    'global_code': '8Q98GRQH+WX'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '５７',
#     'short_name': '５７',
#     'types': ['premise']},
#    {'long_name': '성내로',
#     'short_name': '성내로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '성내1동',
#     'short_name': '성내1동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '강동구',
#     'short_name': '강동구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '134-030',
#     'short_name': '134-030',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 강동구 성내1동 성내로 57',
#   'geometry': {'location': {'lat': 37.528511, 'lng': 127.1268224},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5298599802915,
#      'lng': 127.1281713802915},
#     'southwest': {'lat': 37.52716201970851, 'lng': 127.1254734197085}}},
#   'place_id': 'ChIJz_fwQlilfDURUxRjmop7l7s',
#   'plus_code': {'compound_code': 'G4HG+CP 대한민국 서울특별시',
#    'global_code': '8Q99G4HG+CP'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '１３５',
#     'short_name': '１３５',
#     'types': ['premise']},
#    {'long_name': '종암로',
#     'short_name': '종암로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '종암동',
#     'short_name': '종암동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '성북구',
#     'short_name': '성북구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '136-090',
#     'short_name': '136-090',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 성북구 종암동 종암로 135',
#   'geometry': {'location': {'lat': 37.6020592, 'lng': 127.0321577},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.6034081802915,
#      'lng': 127.0335066802915},
#     'southwest': {'lat': 37.6007102197085, 'lng': 127.0308087197085}}},
#   'place_id': 'ChIJT33rKpu8fDURkaGCAbt23S0',
#   'plus_code': {'compound_code': 'J22J+RV 대한민국 서울특별시',
#    'global_code': '8Q99J22J+RV'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '가마산로',
#     'short_name': '가마산로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '구로구',
#     'short_name': '구로구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['locality', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']}],
#   'formatted_address': '대한민국 서울특별시 구로구 가마산로 235',
#   'geometry': {'location': {'lat': 37.494931, 'lng': 126.886731},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.4962799802915,
#      'lng': 126.8880799802915},
#     'southwest': {'lat': 37.49358201970851, 'lng': 126.8853820197085}}},
#   'place_id': 'ChIJmRBVTBSefDURMQeUuNnWXlU',
#   'plus_code': {'compound_code': 'FVVP+XM 대한민국 서울특별시',
#    'global_code': '8Q98FVVP+XM'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '１７９',
#     'short_name': '１７９',
#     'types': ['premise']},
#    {'long_name': '반포대로',
#     'short_name': '반포대로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '서초3동',
#     'short_name': '서초3동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '서초구',
#     'short_name': '서초구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '137-070',
#     'short_name': '137-070',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 서초구 서초3동 반포대로 179',
#   'geometry': {'location': {'lat': 37.4956054, 'lng': 127.0052504},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.49695438029149,
#      'lng': 127.0065993802915},
#     'southwest': {'lat': 37.49425641970849, 'lng': 127.0039014197085}}},
#   'place_id': 'ChIJWffyGkqhfDURLuilSJqwZLA',
#   'plus_code': {'compound_code': 'F2W4+64 대한민국 서울특별시',
#    'global_code': '8Q99F2W4+64'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '９９',
#     'short_name': '９９',
#     'types': ['premise']},
#    {'long_name': '목동동로',
#     'short_name': '목동동로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '신정6동',
#     'short_name': '신정6동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '양천구',
#     'short_name': '양천구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '158-076',
#     'short_name': '158-076',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 양천구 신정6동 목동동로 99',
#   'geometry': {'location': {'lat': 37.5165667, 'lng': 126.8656763},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5179156802915,
#      'lng': 126.8670252802915},
#     'southwest': {'lat': 37.5152177197085, 'lng': 126.8643273197085}}},
#   'place_id': 'ChIJwfQIp9edfDURwNXXjbRynKo',
#   'plus_code': {'compound_code': 'GV88+J7 대한민국 서울특별시',
#    'global_code': '8Q98GV88+J7'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '가락본동',
#     'short_name': '가락본동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '송파구',
#     'short_name': '송파구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['locality', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']}],
#   'formatted_address': '대한민국 서울특별시 송파구 가락본동 9',
#   'geometry': {'location': {'lat': 37.5019065, 'lng': 127.1271513},
#    'location_type': 'GEOMETRIC_CENTER',
#    'viewport': {'northeast': {'lat': 37.50325548029149,
#      'lng': 127.1285002802915},
#     'southwest': {'lat': 37.50055751970849, 'lng': 127.1258023197085}}},
#   'place_id': 'ChIJA1pC63-vfDURYsWgKqV9nUw',
#   'plus_code': {'compound_code': 'G42G+QV 대한민국 서울특별시',
#    'global_code': '8Q99G42G+QV'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '１２３４',
#     'short_name': '１２３４',
#     'types': ['premise']},
#    {'long_name': '양재대로',
#     'short_name': '양재대로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '방이동',
#     'short_name': '방이동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '송파구',
#     'short_name': '송파구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '138-151',
#     'short_name': '138-151',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 송파구 방이동 양재대로 1234',
#   'geometry': {'location': {'lat': 37.5156549, 'lng': 127.1344002},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5170038802915,
#      'lng': 127.1357491802915},
#     'southwest': {'lat': 37.51430591970851, 'lng': 127.1330512197085}}},
#   'place_id': 'ChIJXYjCr42vfDURBx8az1vtfSY',
#   'plus_code': {'compound_code': 'G48M+7Q 대한민국 서울특별시',
#    'global_code': '8Q99G48M+7Q'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '２８３',
#     'short_name': '２８３',
#     'types': ['premise']},
#    {'long_name': '노원로',
#     'short_name': '노원로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '하계동',
#     'short_name': '하계동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '노원구',
#     'short_name': '노원구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '139-230',
#     'short_name': '139-230',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 노원구 하계동 노원로 283',
#   'geometry': {'location': {'lat': 37.6423605, 'lng': 127.0714027},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.64370948029149,
#      'lng': 127.0727516802915},
#     'southwest': {'lat': 37.6410115197085, 'lng': 127.0700537197085}}},
#   'place_id': 'ChIJQ9zARmW5fDURgrNe_TNJWP4',
#   'plus_code': {'compound_code': 'J3RC+WH 대한민국 서울특별시',
#    'global_code': '8Q99J3RC+WH'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '２０４',
#     'short_name': '２０４',
#     'types': ['premise']},
#    {'long_name': '동작대로',
#     'short_name': '동작대로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '방배본동',
#     'short_name': '방배본동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '서초구',
#     'short_name': '서초구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '137-069',
#     'short_name': '137-069',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 서초구 방배본동 동작대로 204',
#   'geometry': {'location': {'lat': 37.4945959, 'lng': 126.9831279},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.4959448802915,
#      'lng': 126.9844768802915},
#     'southwest': {'lat': 37.4932469197085, 'lng': 126.9817789197085}}},
#   'place_id': 'ChIJIVym0kygfDUR9S_sSnCasQU',
#   'plus_code': {'compound_code': 'FXVM+R7 대한민국 서울특별시',
#    'global_code': '8Q98FXVM+R7'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '３６５',
#     'short_name': '３６５',
#     'types': ['premise']},
#    {'long_name': '연서로',
#     'short_name': '연서로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '불광동',
#     'short_name': '불광동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '은평구',
#     'short_name': '은평구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '122-042',
#     'short_name': '122-042',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 은평구 불광동 연서로 365',
#   'geometry': {'location': {'lat': 37.6283597, 'lng': 126.9287226},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.62970868029149,
#      'lng': 126.9300715802915},
#     'southwest': {'lat': 37.6270107197085, 'lng': 126.9273736197085}}},
#   'place_id': 'ChIJH8IMtZWXfDURVy-L5JUjvM4',
#   'plus_code': {'compound_code': 'JWHH+8F 대한민국 서울특별시',
#    'global_code': '8Q98JWHH+8F'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '４０３',
#     'short_name': '４０３',
#     'types': ['premise']},
#    {'long_name': '노해로',
#     'short_name': '노해로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '창4동',
#     'short_name': '창4동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '도봉구',
#     'short_name': '도봉구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '132-040',
#     'short_name': '132-040',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 도봉구 창4동 노해로 403',
#   'geometry': {'location': {'lat': 37.6533589, 'lng': 127.052682},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.6547078802915,
#      'lng': 127.0540309802915},
#     'southwest': {'lat': 37.6520099197085, 'lng': 127.0513330197085}}},
#   'place_id': 'ChIJTUiMyEW5fDURH_6VenyTTpw',
#   'plus_code': {'compound_code': 'M333+83 대한민국 서울특별시',
#    'global_code': '8Q99M333+83'},
#   'types': ['establishment', 'point_of_interest', 'police']},
#  {'address_components': [{'long_name': '６１７',
#     'short_name': '６１７',
#     'types': ['premise']},
#    {'long_name': '개포로',
#     'short_name': '개포로',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '개포동',
#     'short_name': '개포동',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '강남구',
#     'short_name': '강남구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '135-240',
#     'short_name': '135-240',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 강남구 개포동 개포로 617',
#   'geometry': {'location': {'lat': 37.49349, 'lng': 127.0772119},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.4948389802915,
#      'lng': 127.0785608802915},
#     'southwest': {'lat': 37.49214101970851, 'lng': 127.0758629197085}}},
#   'place_id': 'ChIJY2ee_TGkfDURAWUtC8jBHag',
#   'plus_code': {'compound_code': 'F3VG+9V 대한민국 서울특별시',
#    'global_code': '8Q99F3VG+9V'},
#   'types': ['establishment', 'point_of_interest', 'police']}]

# %%
lats = []
lngs = []

for res in fin_res:
    lats.append(res.get('geometry')['location']['lat'])
    lngs.append(res.get('geometry')['location']['lng'])

print(len(fin_res))
# Out:
# 33

# %%
#3.지도상에 그리기
# (1) 하기전에 설치 !pip install folium
import folium as f

# (2) 지도 focus 위치 정해서 저장
#fm = f.Map(location=[lats[0],lngs[0]], zoom_start=100)
fm = f.Map(location=[37.567,127],zoom_start=12) #적도, 위도 한가운데에 zoom-in 된다.

# (3) 아이콘 찍기
for i in range(0, len(fin_res)):
    f.Marker([lats[i],lngs[i]] ,icon = f.Icon(icon='cloud')).add_to(fm)
    
# (4) 출력
fm
#두 개의 용산 경찰서 찍힘! ( 용산경찰서원효지구대, 용산경찰서 )
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#f.Marker([lat,lng], popup="서울중부경찰서",icon = f.Icon(icon='cloud')).add_to(fm)
#fm
f.Marker([lat,lng], popup="서울중부경찰서",icon = f.Icon(icon='cloud')).add_to(fm2)
fm2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
