# %%
import pandas as pd
df = pd.read_csv("data.csv", encoding='EUC-KR')
df.head()

selections = ['서울특별시','부산광역시', '대구광역시',
                    '경상북도', '경상남도', '광주광역시', '대전광역시', 
                    '울산광역시', '경기도', '충청북도', '충청남도', 
                    '전라북도', '전라남도', '강원도', '인천광역시']

# 발생건수,사상자수,사망자수,중상자수,경상자수,부상신고자수
count1 = [0,0,0,0,0,0] #서울특별시
#print(len(df))
for i in range(len(df)):
    #print(df.iloc[i,4])
    #for slt in selections:
    df2 = df.iloc[i,4]
    if "서울특별시" in df2:
        a = df.iloc[i, [6,7,8,9,10,11]]
        #print(a[0], a[1], a[2], a[3], a[4], a[5])
        count1[0] = count1[0] + a[0]
        count1[1] = count1[1] + a[1]
        count1[2] = count1[2] + a[2]
        count1[3] = count1[3] + a[3]
        count1[4] = count1[4] + a[4]
        count1[5] = count1[5] + a[5]

print(count1)
titles = ['a', 'b', 'c', 'd', 'e', 'f']
import matplotlib.pyplot as plt
plt.plot(titles, count1)
plt.show()
# Out:
# [739, 793, 13, 218, 423, 139]
