# %%
import csv

f = open("seoul.csv", encoding = 'utf-8')
data = csv.reader(f)
next(data)
for row in data:
    try:
        float(row[-1])
    except:
        pass
    else:
        if float(row[-1]) > 37:
            print("날짜 : ", row[0], " / 최고온도 : ", row[-1])
# Out:
# 날짜 :  1919-08-01  / 최고온도 :  37.5
# 날짜 :  1919-08-13  / 최고온도 :  37.3
# 날짜 :  1924-08-09  / 최고온도 :  37.4
# 날짜 :  1930-08-10  / 최고온도 :  37.1
# 날짜 :  1930-08-11  / 최고온도 :  37.4
# 날짜 :  1932-08-01  / 최고온도 :  37.2
# 날짜 :  1932-08-02  / 최고온도 :  37.2
# 날짜 :  1939-07-21  / 최고온도 :  37.7
# 날짜 :  1939-07-22  / 최고온도 :  37.1
# 날짜 :  1939-07-27  / 최고온도 :  37.3
# 날짜 :  1939-07-29  / 최고온도 :  37.6
# 날짜 :  1939-07-30  / 최고온도 :  37.7
# 날짜 :  1939-08-07  / 최고온도 :  37.4
# 날짜 :  1939-08-10  / 최고온도 :  38.2
# 날짜 :  1939-08-21  / 최고온도 :  37.3
# 날짜 :  1939-08-22  / 최고온도 :  37.7
# 날짜 :  1943-08-24  / 최고온도 :  38.2
# 날짜 :  1943-08-25  / 최고온도 :  37.2
# 날짜 :  1943-08-28  / 최고온도 :  37.9
# 날짜 :  1949-08-15  / 최고온도 :  37.7
# 날짜 :  1949-08-16  / 최고온도 :  37.4
# 날짜 :  1958-06-24  / 최고온도 :  37.2
# 날짜 :  1994-07-23  / 최고온도 :  38.2
# 날짜 :  1994-07-24  / 최고온도 :  38.4
# 날짜 :  1994-07-26  / 최고온도 :  37.1
# 날짜 :  2018-07-22  / 최고온도 :  38
# 날짜 :  2018-07-31  / 최고온도 :  38.3
# 날짜 :  2018-08-01  / 최고온도 :  39.6
# ...
