# %%
#제공된 seoul.csv를 사용하여 기상 관측 이래 가장 추웠던 날은 몇도 인지 확인하시오.
import pandas as pd
from tqdm import tqdm_notebook as tn 

seoul = pd.read_csv("seoul.csv", encoding='utf-8')
type(seoul)

seoul1 = seoul.loc[0:,[ '날짜','최저기온(℃)']]
seoul1

#첫번째 정보 저장
date = seoul1.iloc[0,0]
temp = seoul1.iloc[0,1]
for i in range(0,len(seoul1)):
    if (temp >= seoul1.iloc[i,1]) : #저장된 온도와 비교해서 더 낮으면 더 낮은 애 저장
        temp = seoul1.iloc[i,1] 
        date = seoul1.iloc[i,0]

print("날짜: " , date, " / 최저기온 : ", temp)

seoul1['year'] = seoul1['날짜'].apply(lambda e : e.split("-")[0])
seoul1['month'] = seoul1['날짜'].apply(lambda e : e.split("-")[1])

seoul1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-c46675bce037> in <module>
#       3 from tqdm import tqdm_notebook as tn
#       4
# ----> 5 seoul = pd.read_csv("seoul.csv", encoding='utf-8')
#       6 type(seoul)
#       7
#
# ...

# %%
#seoul1.groupby(seoul1['날짜'].apply(lambda e : e.split("-")))['최저기온(℃)'].mean()
#TypeError: unhashable type: 'list'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, *args, **kwargs)
#    1305         try:
# -> 1306             return self._cython_agg_general('mean', **kwargs)
#    1307         except GroupByError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1049                 result, names = self.grouper.aggregate(obj.values, how,
# -> 1050                                                        min_count=min_count)
#    1051             except AssertionError as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in aggregate(self, values, how, axis, min_count)
#    2626         return self._cython_operation('aggregate', values, how, axis,
# ...
